# %% [markdown]
# # Major Work

# %%
lst = []
an = []
ans = []


ans = []

def count_special_character(str1,i): 
    for c in str1:
        if(c.isalpha()):
            ans.insert(i,c)
        i = i+1
        

list1 = ["Go&&l", "&&yal","@*&al","#oyal"]

for i in range(4):
    strg = (str)(input("Enter the name: "))
    lst.insert(i,strg+"")
    
# print(lst)

for j in range(len(lst)):
    splint = lst[j].split(" ")
    an.append(splint)
# print(an)

for r in range(0,len(an)):
    finalans=[]
    for c in range(0,len(an)):
        finalans.append(an[c])
    
    print(finalans)

    for l in range(0,len(finalans[0])):
        ans.insert(l,"-")
    print(ans)

    for m in range (0,len(finalans)+1):
        if(m<len(finalans)):
#             print(finalans[m])
            count_special_character(finalans[m],0)
    # print(ans)
    strg = ""

    for n in range(len(finalans[0])):
        strg = strg+ans[n]
    
    print(strg)

#??????????????????????????????????????????????????????????????????????????????????????????????????????????????????????????


# for i in range(3):
#     strg = (str)(input("Enter the name: "))
#     lst.insert(i,strg+"")
    
# print(lst)

# for j in range(len(lst)):
#     splint = lst[j].split(" ")
#     an.append(splint)
# print(an)

# for r in range(0,len(an)-1):
#     finalans=[]
#     for c in range(0,len(an)):
#         finalans.append(an[c][r])
    
#     print(finalans)
# Out:
# Enter the name: df
# Enter the name: df
# Enter the name: df
# Enter the name: df
# [['df', ''], ['df'], ['df'], ['df']]
# ['-', '-']
# dfdf
# [['df', ''], ['df'], ['df'], ['df']]
# ['-', '-', 'df', 'df', 'df', 'df', '-', '-']
# dfdf
# [['df', ''], ['df'], ['df'], ['df']]
# ['-', '-', 'df', 'df', 'df', 'df', '-', '-', 'df', 'df', 'df', 'df', '-', '-']
# dfdf
# [['df', ''], ['df'], ['df'], ['df']]
# ['-', '-', 'df', 'df', 'df', 'df', '-', '-', 'df', 'df', 'df', 'df', '-', '-', 'df', 'df', 'df', 'df', '-', '-']
# dfdf

# %% [markdown]
# # ACTUAL CODE

# %%
def count(strg):
#     for j in range(0,7):
    j=0
    for c in strg:
#         print(j)
        headers[j].append(c)
        j=j+1
        
    
                
list1 = ["g@urav","gaur@v","gaurav","gaurbv","gburbv"]
# list1 = ["Mu#kan","M$saan","Muskan","M&skan","Muisla"]
header_count = len(list1[0])
headers = [[] for i in range(0, header_count)]

for r in range (0,len(list1)+1):
    if(r<len(list1)):
        print(list1[r])

        count(list1[r])


# print(headers)
# print(sorted(headers[4]))
lst = ""
lst1 =""

finalans = ""
def lstToString(head):
    print(head)
    return ''.join(map(str, head))
    
def count_freq(str1): 
    d = dict()
    for c in str1:
        if(c.isalpha()):
            
            d[c] = d.get(c, 0) + 1
#     a_dictionary = {"a": 1, "b": 2, "c": 3}

    max_key = max(d, key=d.get)
    #ans of the string max key
    return max_key
#     return ans
#     print(max_key)
#     print(max(d))
#     print(d)
for k in range(0,len(headers)):
#     print(len(headers))
#     print(k)
    lst = lstToString(sorted(headers[k]))
#     print(lst)
    finalans += count_freq(lst)

print(finalans)
# Out:
# g@urav
# gaur@v
# gaurav
# gaurbv
# gburbv
# ['g', 'g', 'g', 'g', 'g']
# ['@', 'a', 'a', 'a', 'b']
# ['u', 'u', 'u', 'u', 'u']
# ['r', 'r', 'r', 'r', 'r']
# ['@', 'a', 'a', 'b', 'b']
# ['v', 'v', 'v', 'v', 'v']
# gaurav
