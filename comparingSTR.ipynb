# %%
ans = []
i=0

def count_special_character(string): 
  
    # Declaring variable for special characters 
    special_char= 0
   
    for i in range(0, len(string)):  
    # len(string) function to count the 
    # number of characters in given string.
      
        ch = string[i]
  
        #.isalpha() function checks whether character 
        #is alphabet or not.
        if (string[i].isalpha()):  
            continue
        
        #.isdigit() function checks whether character 
        #is a number or not.
        elif (string[i].isdigit()):
            continue
            
        else: 
            special_char += 1
            
    
    
    
            
    if special_char >= 0:    
        print("String contains {} Special Character/s ".format(special_char))  
#     else:
#         print("There are no Special Characters in this String.")
    return special_char






lst1 = []
an = []
finalans = []

for i in range(3):
    strg = (str)(input("Enter the name: "))
    lst1.insert(i,strg+"")
    
print(lst1)

for j in range(len(lst1)):
    splint = lst1[j].split(" ")
    an.append(splint)
# print(an[0][0])
# print(an[1][0])
# print(an[2][0])

# for(int i=0;i<an.length;i++){
#     for(int j=0;j<an.length;i++){
#         an[j][i]
#     }
# }

for r in range(0,len(an)):
    finalans=[]
    min = 0
    idx = 0
    for c in range(0,len(an)):
        finalans.append(an[c][r])
    for i in range(0,len(finalans)):
        ans.insert(i,count_special_character(finalans[i]))
        print("ans list: ",ans)
    
    min  = ans[0]
    for j in range(len(ans)):
        
        if(min>ans[j]):
            min = ans[j]
            idx = j
            
    print("idx: ",idx)
    print(finalans)
    print(finalans[idx])
# Out:
# Enter the name: @rman ku&&^ si%$ shikhawat
# Enter the name: arman ku#@$ si*&g sh^%@&
# Enter the name: #$rma kumar s&%$ shyifat
# ['@rman ku&&^ si%$ shikhawat', 'arman ku#@$ si*&g sh^%@&', '#$rma kumar s&%$ shyifat']
# String contains 1 Special Character/s
# ans list:  [1]
# String contains 0 Special Character/s
# ans list:  [1, 0]
# String contains 2 Special Character/s
# ans list:  [1, 0, 2]
# idx:  1
# ['@rman', 'arman', '#$rma']
# arman
# String contains 3 Special Character/s
# ans list:  [3, 1, 0, 2]
# String contains 3 Special Character/s
# ans list:  [3, 3, 1, 0, 2]
# String contains 0 Special Character/s
# ans list:  [3, 3, 0, 1, 0, 2]
# idx:  2
# ['ku&&^', 'ku#@$', 'kumar']
# kumar
# String contains 2 Special Character/s
# ans list:  [2, 3, 3, 0, 1, 0, 2]
# String contains 2 Special Character/s
# ans list:  [2, 2, 3, 3, 0, 1, 0, 2]
# String contains 3 Special Character/s
# ans list:  [2, 2, 3, 3, 3, 0, 1, 0, 2]
# idx:  5
# ['si%$', 'si*&g', 's&%$']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-25-191c3be532c7> in <module>
#      83     print("idx: ",idx)
#      84     print(finalans)
# ---> 85     print(finalans[idx])
#      86
#      87
#
# IndexError: list index out of range
